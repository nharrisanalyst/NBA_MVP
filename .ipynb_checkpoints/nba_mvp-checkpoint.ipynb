# %%
import pandas as pd

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
last_year = 2023

# %%
first_year = 1956

# %%
2023 - 1956
# Out:
# 67

# %%
nba_mvp_url = "https://www.basketball-reference.com/awards/mvp.html"

# %%
per_game_player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html" #by year

# %%
per_player_advanced_url = "https://www.basketball-reference.com/leagues/NBA_{year}_advanced.html"

# %%
def get_nba_mvp_df():
    nba_mvp_html = urlopen(nba_mvp_url)
    mvp_soup = BeautifulSoup(nba_mvp_html, "html.parser")
    nba_mvp_table = mvp_soup.find('table')
    nba_mvp_table_headers = [th.getText() for th in nba_mvp_table.findAll("tr")[1].findAll('th')]
    nba_mvp_table_rows =  nba_mvp_table.find("tbody").findAll('tr')
    nba_mvp_table_data = [[td.getText() for td in nba_mvp_table_rows[i].findAll('td')] for i in range(len(nba_mvp_table_rows))]
    nba_mvp_table_rows_season = [th.getText() for th in nba_mvp_table.find("tbody").findAll('th')]
    
    ## combining season with other data as season data is nested
    nba_mvp_table_data_total =[]
    for i in range(len(nba_mvp_table_rows_season)):
        nba_mvp_table_data_total.append([])
        nba_mvp_table_data_total[i].append(nba_mvp_table_rows_season[i])
        nba_mvp_table_data_total[i].extend(nba_mvp_table_data[i])
    
    nba_mvp_df = pd.DataFrame(nba_mvp_table_data_total, columns=nba_mvp_table_headers)
    
    return nba_mvp_df

# %%
#print(nba_mvp_table_data_total)
#print(nba_mvp_table_headers)

nba_mvp_df = get_nba_mvp_df()

# %%
nba_mvp_df.head(10)  ## mvp data frame head
# Out:
#     Season   Lg                 Player Voting Age   Tm   G    MP   PTS   TRB  \
# 0  2022-23  NBA            Joel Embiid    (V)  28  PHI  66  34.6  33.1  10.2
# 1  2021-22  NBA           Nikola Jokić    (V)  26  DEN  74  33.5  27.1  13.8
# 2  2020-21  NBA           Nikola Jokić    (V)  25  DEN  72  34.6  26.4  10.8
# 3  2019-20  NBA  Giannis Antetokounmpo    (V)  25  MIL  63  30.4  29.5  13.6
# 4  2018-19  NBA  Giannis Antetokounmpo    (V)  24  MIL  72  32.8  27.7  12.5
# 5  2017-18  NBA           James Harden    (V)  28  HOU  72  35.4  30.4   5.4
# 6  2016-17  NBA      Russell Westbrook    (V)  28  OKC  81  34.6  31.6  10.7
# 7  2015-16  NBA          Stephen Curry    (V)  27  GSW  79  34.2  30.1   5.4
# 8  2014-15  NBA          Stephen Curry    (V)  26  GSW  80  32.7  23.8   4.3
# 9  2013-14  NBA           Kevin Durant    (V)  25  OKC  81  38.5  32.0   7.4
#
#     AST  STL  BLK   FG%   3P%   FT%    WS WS/48
# 0   4.2  1.0  1.7  .548  .330  .857  12.3  .259
# 1   7.9  1.5  0.9  .583  .337  .810  15.2  .296
# 2   8.3  1.3  0.7  .566  .388  .868  15.6  .301
# 3   5.6  1.0  1.0  .553  .304  .633  11.1  .279
# 4   5.9  1.3  1.5  .578  .256  .729  14.4  .292
# 5   8.8  1.8  0.7  .449  .367  .858  15.4  .289
# 6  10.4  1.6  0.4  .425  .343  .845  13.1  .224
# 7   6.7  2.1  0.2  .504  .454  .908  17.9  .318
# 8   7.7  2.0  0.2  .487  .443  .914  15.7  .288
# 9   5.5  1.3  0.7  .503  .391  .873  19.2  .295

# %%
## get data for everyplayer for season this will be used to find averages for statistics

# %%
print(per_game_player_stats_url.format(year=2023))
# Out:
# https://www.basketball-reference.com/leagues/NBA_2023_per_game.html

# %%
def get_player_year_data_headers(url,year):
    player_data_html = urlopen(url.format(year=year))
    player_soup = BeautifulSoup(player_data_html, "html.parser")
    player_data_table = player_soup.find('table')
    player_table_headers = [th.getText() for th in player_data_table.find('thead').findAll('th')]
    player_table_headers.append('season')
    player_table_headers.pop(0)
    return player_table_headers

# %%
print(get_player_year_data_headers(per_game_player_stats_url,"2023"))
# Out:
# ['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'season']

# %%
def get_player_year_data_data(url,year):
    player_data_html = urlopen(url.format(year=year))
    player_soup = BeautifulSoup(player_data_html, "html.parser")
    player_data_table = player_soup.find('table')
    player_data_table_rows = player_data_table.find('tbody').findAll('tr')
    #print('player_data_table_rows',player_data_table_rows[0])
    player_data_full = [[td.getText() for td in player_data_table_rows[i].findAll('td')] for i in range(len(player_data_table_rows))]
    
    for i in range(len(player_data_full)):
        player_data_full[i].append(year)
    
    return player_data_full

# %%
## making multiple calls becuase off rate limits 29 calls

# %%
def get_player_year_data(url, first_year_input, last_year_input):
    headers = get_player_year_data_headers(url,"2023")
    player_data = []
    for year in range(first_year_input, last_year_input+1):
        print(year)
        player_data.extend(get_player_year_data_data(url,year))
        
    player_df = pd.DataFrame(player_data, columns=headers)
    return player_df

# %%
player_per_game_df_1980 = get_player_year_data(per_game_player_stats_url, first_year, 1980)
# Out:
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980

# %%
pplayer_per_game_df_2001 = get_player_year_data(per_game_player_stats_url, 1981, 2001)
# Out:
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001

# %%
pplayer_per_game_df_2023 = get_player_year_data(per_game_player_stats_url, 2002, last_year)
# Out:
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023

# %%
all_player_game_data = [player_per_game_df_1980,pplayer_per_game_df_2001, pplayer_per_game_df_2023]

# %%
all_player_game_data_df = pd.concat(all_player_game_data)

# %%
all_player_game_data_df = all_player_game_data_df.dropna()

# %%
all_player_game_data_df.head(25)
# Out:
#             Player Pos Age   Tm   G GS    MP   FG   FGA   FG%  ... ORB DRB  \
# 0     Paul Arizin*  SF  27  PHW  72     37.8  8.6  19.1  .448  ...
# 1    Jesse Arnelle  PF  22  FTW  31     13.2  1.7   5.3  .317  ...
# 2        Dick Atha  SG  24  NYK  25     11.5  1.4   3.5  .409  ...
# 3    Jim Baechtold  SF  28  NYK  70     24.8  3.8   9.9  .386  ...
# 4    Ernie Barrett  SG  26  BOS  72     20.2  2.9   7.4  .388  ...
# 5       Ernie Beck  SG  24  PHW  67     15.0  2.0   5.2  .387  ...
# 6       Don Bielke   C  23  FTW   7      5.4  0.7   1.3  .556  ...
# 7      Carl Braun*  SG  28  NYK  72     32.2  5.5  14.8  .372  ...
# 8    Frankie Brian  PG  32  FTW  37     18.4  2.1   7.1  .297  ...
# 9     Nat Clifton*  PF  33  NYK  64     24.0  3.3   8.5  .394  ...
# 10    Jack Coleman  PF  31  TOT  75     36.5  5.2  12.6  .412  ...
# 11    Jack Coleman  PF  31  ROC  34     40.3  5.7  13.9  .412  ...
# 12    Jack Coleman  PF  31  STL  41     33.4  4.8  11.5  .412  ...
# 13       Ed Conlin  SF  22  SYR  66     21.6  3.2   8.7  .368  ...
# 14   Chuck Cooper*  SF  29  TOT  67     17.1  1.5   4.6  .328  ...
# 15   Chuck Cooper*   F  29  STL  35     16.4  1.7   4.9  .337  ...
# 16   Chuck Cooper*  SF  29  FTW  32     17.8  1.3   4.3  .316  ...
# 17      Bob Cousy*  PG  27  BOS  72     38.4  6.1  17.0  .360  ...
# 18       Red Davis   C  23  ROC   3      5.3  0.0   2.0  .000  ...
# 19      Walt Davis  PF  25  PHW  70     15.7  1.8   4.8  .369  ...
# 20  George Dempsey  PG  26  PHW  72     20.1  1.8   3.7  .475  ...
# 21    Corky Devlin  SG  24  FTW  69     22.2  2.9   7.8  .370  ...
# 22    Walter Dukes   C  25  NYK  60     21.5  2.5   6.2  .403  ...
# 23     Dick Farley  SG  23  SYR  72     19.8  2.3   6.3  .373  ...
# 25  Ron Feiereisel   G  24  MNL  10      5.9  0.8   2.8  .286  ...
#
#      TRB  AST STL BLK TOV   PF   PTS  season
# 0    7.5  2.6              3.9  24.2  1956.0
# 1    5.5  0.6              1.9   4.7  1956.0
# 2    1.7  1.3              1.6   3.7  1956.0
# 3    3.1  2.3              2.2  11.0  1956.0
# 4    3.4  2.4              2.6   7.0  1956.0
# 5    2.9  1.2              1.3   5.2  1956.0
# 6    1.3  0.1              1.3   2.0  1956.0
# 7    3.6  4.1              3.0  15.4  1956.0
# 8    2.4  2.0              1.7   6.2  1956.0
# 9    6.0  2.4              3.0   8.8  1956.0
# 10   9.2  3.9              3.2  12.8  1956.0
# 11  10.1  4.3              3.6  14.1  1956.0
# 12   8.4  3.6              3.0  11.7  1956.0
# 13   4.9  2.2              1.8   8.2  1956.0
# 14   3.6  1.3              2.1   4.5  1956.0
# 15   3.9  1.7              2.0   5.1  1956.0
# 16   3.2  0.9              2.2   3.9  1956.0
# 17   6.8  8.9              2.9  18.8  1956.0
# 18   1.3  0.3              0.7   0.7  1956.0
# 19   3.9  0.8              3.3   4.6  1956.0
# 20   3.7  2.8              2.0   4.7  1956.0
# 21   2.5  2.0              1.7   7.9  1956.0
# 22   7.4  0.7              3.5   7.8  1956.0
# 23   2.3  2.1              2.1   6.7  1956.0
# 25   0.6  0.6              0.9   3.0  1956.0
#
# [25 rows x 30 columns]

# %%
all_player_game_data_df.tail(25)
# Out:
#                    Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 13884      Grant Williams  PF  24  BOS  79  23  25.9  2.7   6.0  .454  ...
# 13885      Jalen Williams  SG  21  OKC  75  62  30.3  5.5  10.6  .521  ...
# 13886     Jaylin Williams   C  20  OKC  49  36  18.7  2.1   4.8  .436  ...
# 13887  Jeenathan Williams  SG  23  POR   5   4  25.4  4.8   7.8  .615  ...
# 13889    Kenrich Williams  PF  28  OKC  53  10  22.8  3.4   6.5  .517  ...
1.8  3.1   1.4  1.0  0.1  0.8  1.6   4.4  2023.0
# 13906  0.8  2.2  3.0  10.2  1.1  0.1  4.1  1.4  26.2  2023.0
# 13907  0.9  1.7  2.6   0.2  0.2  0.2  0.4  1.8   4.4  2023.0
# 13908  1.7  2.6  4.3   0.7  0.2  0.3  0.9  2.2   6.5  2023.0
# 13909  3.1  6.8  9.9   1.0  0.4  1.3  1.5  2.9  10.8  2023.0
#
# [25 rows x 30 columns]

# %%
## saved as csv 

all_player_game_data_df.to_csv('data/player_game.csv')

# %%
nba_mvp_df.to_csv('data/nba_mvp.csv')

# %%
adv_player_data_df_1980 = get_player_year_data(per_player_advanced_url, first_year, 1980)
# Out:
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980

# %%
adv_player_data_df_2001 = get_player_year_data(per_player_advanced_url, 1981, 2001)
# Out:
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001

# %%
adv_player_data_df_2023 = get_player_year_data(per_player_advanced_url, 2002, last_year)
# Out:
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023

# %%
adv_player_all = [adv_player_data_df_1980,adv_player_data_df_2001,adv_player_data_df_2023]

# %%
adv_player_all_df = pd.concat(adv_player_all)

# %%
adv_player_all_df = adv_player_all_df.dropna()

# %%
adv_player_all_df.head() ## few sanity checks
# Out:
#           Player Pos Age   Tm   G    MP   PER   TS% 3PAr   FTr  ...   OWS  \
# 0   Paul Arizin*  SF  27  PHW  72  2724  21.3  .526       .454  ...  10.2
# 1  Jesse Arnelle  PF  22  FTW  31   409  12.6  .378       .421  ...  -0.6
# 2      Dick Atha  SG  24  NYK  25   288  11.4  .466       .307  ...   0.3
# 3  Jim Baechtold  SF  28  NYK  70  1738  14.2  .467       .419  ...   2.3
# 4  Ernie Barrett  SG  26  BOS  72  1451  11.2  .433       .221  ...   0.5
#
#    DWS    WS   WS/48   OBPM DBPM BPM VORP  season
# 0  2.0  12.2    .214                       1956.0
# 1  0.6   0.0  -0.001                       1956.0
# 2  0.2   0.5    .076                       1956.0
# 3  0.8   3.2    .088                       1956.0
# 4  1.0   1.5    .051                       1956.0
#
# [5 rows x 29 columns]

# %%
adv_player_all_df.tail()
# Out:
#                Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ...  \
# 13905  Thaddeus Young  PF  34  TOR  54   795  14.1  .573  .172  .131  ...
# 13906      Trae Young  PG  24  ATL  73  2541  22.0  .573  .331  .460  ...
# 13907  Omer Yurtseven   C  24  MIA   9    83  16.7  .675  .259  .222  ...
# 13908     Cody Zeller   C  30  MIA  15   217  16.4  .659  .034  .593  ...
# 13909     Ivica Zubac   C  25  LAC  76  2170  16.7  .661  .004  .463  ...
#
#        OWS  DWS   WS WS/48    OBPM  DBPM   BPM VORP  season
# 13905  0.7  1.1  1.8  .109    -1.8   1.9   0.1  0.4  2023.0
# 13906  5.3  1.4  6.7  .126     5.3  -2.0   3.3  3.4  2023.0
# 13907  0.2  0.1  0.3  .159    -2.5  -1.5  -3.9  0.0  2023.0
# 13908  0.4  0.3  0.7  .147    -2.0  -0.7  -2.8  0.0  2023.0
# 13909  3.8  2.9  6.7  .149    -1.1   0.2  -0.9  0.6  2023.0
#
# [5 rows x 29 columns]

# %%
adv_player_all_df.to_csv("data/player_adv.csv")
